# %%
import pandas as pd
import json
import os
os.chdir(r"C:\Users\Mohamed Kani P K\Downloads")

with open('Final_tanglsih_json.json', 'r',encoding='utf-8') as f:
    data = json.load(f)

# %%
entity_names = ['PER', 'LOC', 'ORG', 'PRODUCT', 'TIME', 'MONEY','EVENT','DATE','PROFESSION','FACILITY','CONTENT','FIELD OF STUDY','PROCESS','DOMAIN','ATTRIBUTE','GPE','YEAR','GOVERNMENT','ACTIVITY','EMOTION','ACTION','ENTERTAINMENT']
train_data = data['annotations']
train_data = [tuple(i) for i in train_data]

# %%
train_data
# Out:
# [('En mapla odi poi irukkan\r', {'entities': [[3, 8, 'PER']]}),
#  ('Naan college ku poren\r', {'entities': [[5, 12, 'ORG']]}),
#  ('En akka ku gift vaangi koduthen\r',
#   {'entities': [[3, 7, 'PER'], [11, 15, 'PRODUCT']]}),
#  ('Office ku late aagi iruken\r', {'entities': [[0, 6, 'ORG']]}),
#  ('Naan London ku ponen\r', {'entities': [[0, 4, 'PER'], [5, 11, 'LOC']]}),
#  ('En friend kalyanam nadakuthu\r',
#   {'entities': [[3, 9, 'PER'], [10, 18, 'EVENT']]}),
#  ('Namma ooru Chennai\r', {'entities': [[11, 18, 'LOC']]}),
#  ('Naan school la padichiruken\r', {'entities': [[5, 11, 'ORG']]}),
#  ('En amma office la work pannuva\r',
#   {'entities': [[3, 7, 'PER'], [8, 14, 'ORG']]}),
#  ('En friend car kitta poyi vandhurukka\r',
#   {'entities': [[3, 9, 'PER'], [10, 13, 'PRODUCT']]}),
#  ('Naan India ku poiruken\r', {'entities': [[0, 4, 'PER'], [5, 10, 'LOC']]}),
#  ('En teacher oru book kodutharu\r',
#   {'entities': [[3, 10, 'PER'], [15, 19, 'PRODUCT']]}),
# ...

# %%
for i in train_data:
    if i[1]['entities'] == []:
        i[1]['entities'] = (0, 0, entity_name)
    else:
        i[1]['entities'][0] = tuple(i[1]['entities'][0])

# %%
train_data
# Out:
# [('En mapla odi poi irukkan\r', {'entities': [(3, 8, 'PER')]}),
#  ('Naan college ku poren\r', {'entities': [(5, 12, 'ORG')]}),
#  ('En akka ku gift vaangi koduthen\r',
#   {'entities': [(3, 7, 'PER'), [11, 15, 'PRODUCT']]}),
#  ('Office ku late aagi iruken\r', {'entities': [(0, 6, 'ORG')]}),
#  ('Naan London ku ponen\r', {'entities': [(0, 4, 'PER'), [5, 11, 'LOC']]}),
#  ('En friend kalyanam nadakuthu\r',
#   {'entities': [(3, 9, 'PER'), [10, 18, 'EVENT']]}),
#  ('Namma ooru Chennai\r', {'entities': [(11, 18, 'LOC')]}),
#  ('Naan school la padichiruken\r', {'entities': [(5, 11, 'ORG')]}),
#  ('En amma office la work pannuva\r',
#   {'entities': [(3, 7, 'PER'), [8, 14, 'ORG']]}),
#  ('En friend car kitta poyi vandhurukka\r',
#   {'entities': [(3, 9, 'PER'), [10, 13, 'PRODUCT']]}),
#  ('Naan India ku poiruken\r', {'entities': [(0, 4, 'PER'), [5, 10, 'LOC']]}),
#  ('En teacher oru book kodutharu\r',
#   {'entities': [(3, 10, 'PER'), [15, 19, 'PRODUCT']]}),
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming entity_names is defined somewhere
entity_counts = {entity: 0 for entity in entity_names}

# Assuming train_data is defined somewhere
for _, annot in train_data:
    entities = annot['entities']
    for entity in entities:
        entity_type = entity[2]
        if entity_type in entity_counts:
            entity_counts[entity_type] += 1

# Filter out entities with count 0
x_labels = [entity_type for entity_type, count in entity_counts.items() if count > 0]
y_values = [count for count in entity_counts.values() if count > 0]

# Bar Chart
plt.figure(figsize=(8, 6))
plt.bar(x_labels, y_values, color='skyblue')
plt.xlabel('Entity Types')
plt.ylabel('Counts')
plt.title('Counts of Entities')
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
len(train_data)
# Out:
# 136

# %%
import pandas as pd
import json
import os
os.chdir(r"C:\Users\Mohamed Kani P K\Downloads")

with open('annotations (5).json', 'r',encoding='utf-8') as f:
    data = json.load(f)

# %%
data
# Out:
# {'classes': ['PRODUCT',
#   'ORG',
#   'LOC',
#   'PER',
#   'TIME',
#   'MONEY',
#   'EVENT',
#   'DATE',
#   'PROFESSION',
#   'FACILITY',
#   'CONTENT',
#   'FIELD OF STUDY',
#   'PROCESS',
#   'DOMAIN',
#   'ATTRIBUTE',
#   'GPE',
#   'YEAR',
#   'GOVERNMENT',
#   'ACTIVITY',
#   'EMOTION',
#   'ACTION',
#   'ENTERTAINMENT'],
#  'annotations': [['Naan rendu naal Thailand-ku irunthen.\r',
#    {'entities': [[0, 4, 'PER'], [5, 15, 'TIME'], [16, 27, 'LOC']]}],
#   ['Naan Gmail-oda email send panniruken.\r',
#    {'entities': [[0, 4, 'PER'], [5, 14, 'PRODUCT'], [15, 20, 'CONTENT']]}],
#   ['Naan rendu perum Italy ponaanga.\r',
#    {'entities': [[0, 4, 'PER'], [17, 22, 'LOC']]}],
#   ['Naan Facebook-oda friend request send seiraen.\r',
#    {'entities': [[0, 4, 'PER'], [5, 17, 'ORG'], [18, 32, 'CONTENT']]}],
#   ['Naan rendu naal Spain-ku irunthen.\r',
#    {'entities': [[0, 4, 'PER'], [5, 15, 'TIME'], [16, 24, 'LOC']]}],
#   ['Naan Twitter-oda tweet post seiraen.\r',
# ...

# %%
entity_names = ['PER', 'LOC', 'ORG', 'PRODUCT', 'TIME', 'MONEY','EVENT','DATE','PROFESSION','FACILITY','CONTENT','FIELD OF STUDY','PROCESS','DOMAIN','ATTRIBUTE','GPE','YEAR','GOVERNMENT','ACTIVITY','EMOTION','ACTION','ENTERTAINMENT']
train_data1 = data['annotations']
train_data1 = [tuple(i) for i in train_data1]

# %%
for i in train_data1:
    if i[1]['entities'] == []:
        i[1]['entities'] = (0, 0, entity_name)
    else:
        i[1]['entities'][0] = tuple(i[1]['entities'][0])

# %%
train_data1
# Out:
# [('Naan rendu naal Thailand-ku irunthen.\r',
#   {'entities': [(0, 4, 'PER'), [5, 15, 'TIME'], [16, 27, 'LOC']]}),
#  ('Naan Gmail-oda email send panniruken.\r',
#   {'entities': [(0, 4, 'PER'), [5, 14, 'PRODUCT'], [15, 20, 'CONTENT']]}),
#  ('Naan rendu perum Italy ponaanga.\r',
#   {'entities': [(0, 4, 'PER'), [17, 22, 'LOC']]}),
#  ('Naan Facebook-oda friend request send seiraen.\r',
#   {'entities': [(0, 4, 'PER'), [5, 17, 'ORG'], [18, 32, 'CONTENT']]}),
#  ('Naan rendu naal Spain-ku irunthen.\r',
#   {'entities': [(0, 4, 'PER'), [5, 15, 'TIME'], [16, 24, 'LOC']]}),
#  ('Naan Twitter-oda tweet post seiraen.\r',
#   {'entities': [(0, 4, 'PER'), [5, 16, 'ORG'], [17, 22, 'CONTENT']]}),
#  ('Naan rendu perum Canada ponaanga.\r',
#   {'entities': [(0, 4, 'PER'), [17, 23, 'LOC']]}),
#  ('Naan Uber-oda cab book panniruken.\r',
#   {'entities': [(0, 4, 'PER'), [5, 13, 'ORG'], [14, 17, 'PRODUCT']]}),
#  ('Naan rendu naal US-ku irunthen.\r',
# ...

# %%
len(train_data1)
# Out:
# 155

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming entity_names is defined somewhere
entity_counts = {entity: 0 for entity in entity_names}

# Assuming train_data is defined somewhere
for _, annot in train_data:
    entities = annot['entities']
    for entity in entities:
        entity_type = entity[2]
        if entity_type in entity_counts:
            entity_counts[entity_type] += 1

# Filter out entities with count 0
x_labels = [entity_type for entity_type, count in entity_counts.items() if count > 0]
y_values = [count for count in entity_counts.values() if count > 0]

# Horizontal Bar Chart
plt.figure(figsize=(8, 6))
plt.barh(x_labels, y_values, color='lightgreen')  # Changing color to lightgreen
plt.xlabel('Counts')
plt.ylabel('Entity Types')
plt.title('Counts of Entities')
plt.tight_layout()

plt.show()

# %%
# Append train_data1 to train_data
train_data.extend(train_data1)

# Now train_data contains all the data
print(train_data)
# Out:
# [('En mapla odi poi irukkan\r', {'entities': [(3, 8, 'PER')]}), ('Naan college ku poren\r', {'entities': [(5, 12, 'ORG')]}), ('En akka ku gift vaangi koduthen\r', {'entities': [(3, 7, 'PER'), [11, 15, 'PRODUCT']]}), ('Office ku late aagi iruken\r', {'entities': [(0, 6, 'ORG')]}), ('Naan London ku ponen\r', {'entities': [(0, 4, 'PER'), [5, 11, 'LOC']]}), ('En friend kalyanam nadakuthu\r', {'entities': [(3, 9, 'PER'), [10, 18, 'EVENT']]}), ('Namma ooru Chennai\r', {'entities': [(11, 18, 'LOC')]}), ('Naan school la padichiruken\r', {'entities': [(5, 11, 'ORG')]}), ('En amma office la work pannuva\r', {'entities': [(3, 7, 'PER'), [8, 14, 'ORG']]}), ('En friend car kitta poyi vandhurukka\r', {'entities': [(3, 9, 'PER'), [10, 13, 'PRODUCT']]}), ('Naan India ku poiruken\r', {'entities': [(0, 4, 'PER'), [5, 10, 'LOC']]}), ('En teacher oru book kodutharu\r', {'entities': [(3, 10, 'PER'), [15, 19, 'PRODUCT']]}), ('Naan bank la pesitten\r', {'entities': [(5, 9, 'ORG')]}), ('En brother ku exam i
# ...

# %%
len(train_data)
# Out:
# 291

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming entity_names is defined somewhere
entity_counts = {entity: 0 for entity in entity_names}

# Assuming train_data is defined somewhere
for _, annot in train_data:
    entities = annot['entities']
    for entity in entities:
        entity_type = entity[2]
        if entity_type in entity_counts:
            entity_counts[entity_type] += 1

# Filter out entities with count 0
x_labels = [entity_type for entity_type, count in entity_counts.items() if count > 0]
y_values = [count for count in entity_counts.values() if count > 0]

# Bar Chart
plt.figure(figsize=(8, 6))
plt.bar(x_labels, y_values, color='lightpink')
plt.xlabel('Entity Types')
plt.ylabel('Counts')
plt.title('Counts of Entities')
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
import pandas as pd
import json
import os
os.chdir(r"C:\Users\Mohamed Kani P K\Downloads")

with open('annotations.json', 'r',encoding='utf-8') as f:
    data = json.load(f)

# %%
data
# Out:
# {'classes': ['PER',
#   'LOC',
#   'ORG',
#   'PRODUCT',
#   'TIME',
#   'MONEY',
#   'EVENT',
#   'DATE',
#   'PROFESSION',
#   'FACILITY',
#   'CONTENT',
#   'FIELD OF STUDY',
#   'PROCESS',
#   'DOMAIN',
#   'ATTRIBUTE',
#   'GPE',
#   'YEAR',
#   'GOVERNMENT',
#   'ACTIVITY',
#   'EMOTION',
#   'ACTION',
#   'ENTERTAINMENT'],
#  'annotations': [['Intha restaurant Chinese food serve seiraanga.\r',
#    {'entities': [[6, 16, 'FACILITY'], [17, 29, 'PRODUCT']]}],
#   ['Naan Amazon-oda Prime member-a irukaen.\r',
#    {'entities': [[5, 15, 'ORG'], [16, 21, 'PRODUCT']]}],
#   ['Naan rendu perum Singapore ponaanga.\r',
#    {'entities': [[0, 4, 'PER'], [17, 26, 'LOC']]}],
#   ['Intha car Maruti Suzuki brand.\r',
#    {'entities': [[6, 9, 'PRODUCT'], [10, 23, 'ORG']]}],
#   ['Naan Car-oda insurance renewal panniruken.\r',
#    {'entities': [[0, 4, 'PER'], [5, 12, 'PRODUCT']]}],
#   ['Naan ippa Hyderabad-ku poren.\r',
#    {'entities': [[0, 4, 'PER'], [10, 22, 'LOC']]}],
# ...

# %%
entity_names = ['PER', 'LOC', 'ORG', 'PRODUCT', 'TIME', 'MONEY','EVENT','DATE','PROFESSION','FACILITY','CONTENT','FIELD OF STUDY','PROCESS','DOMAIN','ATTRIBUTE','GPE','YEAR','GOVERNMENT','ACTIVITY','EMOTION','ACTION','ENTERTAINMENT']
train_data1 = data['annotations']
train_data1 = [tuple(i) for i in train_data1]

# %%
train_data1
# Out:
# [('Intha restaurant Chinese food serve seiraanga.\r',
#   {'entities': [[6, 16, 'FACILITY'], [17, 29, 'PRODUCT']]}),
#  ('Naan Amazon-oda Prime member-a irukaen.\r',
#   {'entities': [[5, 15, 'ORG'], [16, 21, 'PRODUCT']]}),
#  ('Naan rendu perum Singapore ponaanga.\r',
#   {'entities': [[0, 4, 'PER'], [17, 26, 'LOC']]}),
#  ('Intha car Maruti Suzuki brand.\r',
#   {'entities': [[6, 9, 'PRODUCT'], [10, 23, 'ORG']]}),
#  ('Naan Car-oda insurance renewal panniruken.\r',
#   {'entities': [[0, 4, 'PER'], [5, 12, 'PRODUCT']]}),
#  ('Naan ippa Hyderabad-ku poren.\r',
#   {'entities': [[0, 4, 'PER'], [10, 22, 'LOC']]}),
#  ('En manager Office-la meeting conduct seiraar.\r',
#   {'entities': [[3, 10, 'PER'], [11, 20, 'ORG']]}),
#  ('Naan Adidas brand-oda shoes vaangittu vandhen.\r',
#   {'entities': [[5, 11, 'ORG'], [22, 27, 'PRODUCT']]}),
#  ('Naan rendu naal Italy-ku irunthen.\r',
#   {'entities': [[0, 4, 'PER'], [16, 24, 'LOC']]}),
# ...

# %%
len(train_data1)
# Out:
# 54

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming entity_names is defined somewhere
entity_counts = {entity: 0 for entity in entity_names}

# Assuming train_data is defined somewhere
for _, annot in train_data:
    entities = annot['entities']
    for entity in entities:
        entity_type = entity[2]
        if entity_type in entity_counts:
            entity_counts[entity_type] += 1

# Filter out entities with count 0
x_labels = [entity_type for entity_type, count in entity_counts.items() if count > 0]
y_values = [count for count in entity_counts.values() if count > 0]

# Bar Chart
plt.figure(figsize=(8, 6))
plt.bar(x_labels, y_values, color='skyblue')
plt.xlabel('Entity Types')
plt.ylabel('Counts')
plt.title('Counts of Entities')
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
for i in train_data1:
    if i[1]['entities'] == []:
        i[1]['entities'] = (0, 0, entity_name)
    else:
        i[1]['entities'][0] = tuple(i[1]['entities'][0])

# %%
train_data.extend(train_data1)

# Store the result in train1
train_data
# Out:
# [('En mapla odi poi irukkan\r', {'entities': [(3, 8, 'PER')]}),
#  ('Naan college ku poren\r', {'entities': [(5, 12, 'ORG')]}),
#  ('En akka ku gift vaangi koduthen\r',
#   {'entities': [(3, 7, 'PER'), [11, 15, 'PRODUCT']]}),
#  ('Office ku late aagi iruken\r', {'entities': [(0, 6, 'ORG')]}),
#  ('Naan London ku ponen\r', {'entities': [(0, 4, 'PER'), [5, 11, 'LOC']]}),
#  ('En friend kalyanam nadakuthu\r',
#   {'entities': [(3, 9, 'PER'), [10, 18, 'EVENT']]}),
#  ('Namma ooru Chennai\r', {'entities': [(11, 18, 'LOC')]}),
#  ('Naan school la padichiruken\r', {'entities': [(5, 11, 'ORG')]}),
#  ('En amma office la work pannuva\r',
#   {'entities': [(3, 7, 'PER'), [8, 14, 'ORG']]}),
#  ('En friend car kitta poyi vandhurukka\r',
#   {'entities': [(3, 9, 'PER'), [10, 13, 'PRODUCT']]}),
#  ('Naan India ku poiruken\r', {'entities': [(0, 4, 'PER'), [5, 10, 'LOC']]}),
#  ('En teacher oru book kodutharu\r',
#   {'entities': [(3, 10, 'PER'), [15, 19, 'PRODUCT']]}),
# ...

# %%
len(train_data)
# Out:
# 345

# %%
import pandas as pd
import json
import os
os.chdir(r"C:\Users\Mohamed Kani P K\Downloads")

with open('annotations (8).json', 'r',encoding='utf-8') as f:
    data = json.load(f)
data
# Out:
# {'classes': ['PRODUCT',
#   'ORG',
#   'LOC',
#   'PER',
#   'TIME',
#   'MONEY',
#   'EVENT',
#   'DATE',
#   'PROFESSION',
#   'FACILITY',
#   'CONTENT',
#   'FIELD OF STUDY',
#   'PROCESS',
#   'DOMAIN',
#   'ATTRIBUTE',
#   'GPE',
#   'YEAR',
#   'GOVERNMENT',
#   'ACTIVITY',
#   'EMOTION',
#   'ACTION',
#   'ENTERTAINMENT',
#   'MOVIE',
#   'LANGUAGE',
#   'QUANTITY'],
#  'annotations': [['Rajini ah vida akshay mass ah irukane\r',
#    {'entities': [[0, 6, 'PER'], [15, 21, 'PER'], [22, 26, 'ATTRIBUTE']]}],
#   [' Thala koda compare panna yarukum thakuthi kidaiyathu mind it\r',
#    {'entities': [[1, 6, 'PER']]}],
#   [' Paruthiveeran Karthi Back  Lokesh Kangaraj Screenplay\r',
#    {'entities': [[1, 21, 'PER'], [28, 43, 'PER']]}],
#   [' Supper dhanush Anna mass waiting asuran\r',
#    {'entities': [[8, 20, 'PER'], [26, 33, 'TIME'], [34, 40, 'MOVIE']]}],
#   [' Vera lvl thalaiva u r great\r',
#    {'entities': [[1, 9, 'EMOTION'], [10, 18, 'PER']]}],
# ...

# %%
entity_names = ['PER', 'LOC', 'ORG', 'PRODUCT', 'TIME', 'MONEY','EVENT','DATE','PROFESSION','FACILITY','CONTENT','FIELD OF STUDY','PROCESS','DOMAIN','ATTRIBUTE','GPE','YEAR','GOVERNMENT','ACTIVITY','EMOTION','ACTION','ENTERTAINMENT','MOVIE','LANGUAGE','QUANTITY']
train_data1 = data['annotations']
train_data1 = [tuple(i) for i in train_data1]

# %%
train_data1
# Out:
# [('Rajini ah vida akshay mass ah irukane\r',
#   {'entities': [[0, 6, 'PER'], [15, 21, 'PER'], [22, 26, 'ATTRIBUTE']]}),
#  (' Thala koda compare panna yarukum thakuthi kidaiyathu mind it\r',
#   {'entities': [[1, 6, 'PER']]}),
#  (' Paruthiveeran Karthi Back  Lokesh Kangaraj Screenplay\r',
#   {'entities': [[1, 21, 'PER'], [28, 43, 'PER']]}),
#  (' Supper dhanush Anna mass waiting asuran\r',
#   {'entities': [[8, 20, 'PER'], [26, 33, 'TIME'], [34, 40, 'MOVIE']]}),
#  (' Vera lvl thalaiva u r great\r',
#   {'entities': [[1, 9, 'EMOTION'], [10, 18, 'PER']]}),
#  (' Pattaya kelapitey Siva!!!  Awesome!!!\r',
#   {'entities': [[19, 23, 'PER'], [28, 38, 'EMOTION']]}),
#  (' Boni kapoor sir ini entha update illama ethum release panathinga sir,  intha chinna pasanga tholla thanga mudiyala\r',
#   {'entities': [[1, 12, 'PER'],
#     [27, 33, 'CONTENT'],
#     [47, 54, 'EVENT'],
#     [78, 92, 'EVENT']]}),
#  (' Looks thrilling, thala get up super as lawyer , dai pandey neeya da\r',
# ...

# %%
for i in train_data1:
    if i[1]['entities'] == []:
        i[1]['entities'] = (0, 0, entity_name)
    else:
        i[1]['entities'][0] = tuple(i[1]['entities'][0])

# %%
train_data.extend(train_data1)

# Store the result in train1
train_data
# Out:
# [('En mapla odi poi irukkan\r', {'entities': [(3, 8, 'PER')]}),
#  ('Naan college ku poren\r', {'entities': [(5, 12, 'ORG')]}),
#  ('En akka ku gift vaangi koduthen\r',
#   {'entities': [(3, 7, 'PER'), [11, 15, 'PRODUCT']]}),
#  ('Office ku late aagi iruken\r', {'entities': [(0, 6, 'ORG')]}),
#  ('Naan London ku ponen\r', {'entities': [(0, 4, 'PER'), [5, 11, 'LOC']]}),
#  ('En friend kalyanam nadakuthu\r',
#   {'entities': [(3, 9, 'PER'), [10, 18, 'EVENT']]}),
#  ('Namma ooru Chennai\r', {'entities': [(11, 18, 'LOC')]}),
#  ('Naan school la padichiruken\r', {'entities': [(5, 11, 'ORG')]}),
#  ('En amma office la work pannuva\r',
#   {'entities': [(3, 7, 'PER'), [8, 14, 'ORG']]}),
#  ('En friend car kitta poyi vandhurukka\r',
#   {'entities': [(3, 9, 'PER'), [10, 13, 'PRODUCT']]}),
#  ('Naan India ku poiruken\r', {'entities': [(0, 4, 'PER'), [5, 10, 'LOC']]}),
#  ('En teacher oru book kodutharu\r',
#   {'entities': [(3, 10, 'PER'), [15, 19, 'PRODUCT']]}),
# ...

# %%
len(train_data)
# Out:
# 413

# %%
train_data
# Out:
# [('En mapla odi poi irukkan\r', {'entities': [(3, 8, 'PER')]}),
#  ('Naan college ku poren\r', {'entities': [(5, 12, 'ORG')]}),
#  ('En akka ku gift vaangi koduthen\r',
#   {'entities': [(3, 7, 'PER'), [11, 15, 'PRODUCT']]}),
#  ('Office ku late aagi iruken\r', {'entities': [(0, 6, 'ORG')]}),
#  ('Naan London ku ponen\r', {'entities': [(0, 4, 'PER'), [5, 11, 'LOC']]}),
#  ('En friend kalyanam nadakuthu\r',
#   {'entities': [(3, 9, 'PER'), [10, 18, 'EVENT']]}),
#  ('Namma ooru Chennai\r', {'entities': [(11, 18, 'LOC')]}),
#  ('Naan school la padichiruken\r', {'entities': [(5, 11, 'ORG')]}),
#  ('En amma office la work pannuva\r',
#   {'entities': [(3, 7, 'PER'), [8, 14, 'ORG']]}),
#  ('En friend car kitta poyi vandhurukka\r',
#   {'entities': [(3, 9, 'PER'), [10, 13, 'PRODUCT']]}),
#  ('Naan India ku poiruken\r', {'entities': [(0, 4, 'PER'), [5, 10, 'LOC']]}),
#  ('En teacher oru book kodutharu\r',
#   {'entities': [(3, 10, 'PER'), [15, 19, 'PRODUCT']]}),
# ...

# %%
import pandas as pd
import json
import os
os.chdir(r"C:\Users\Mohamed Kani P K\Downloads")

with open('annotations (6).json', 'r',encoding='utf-8') as f:
    data = json.load(f)
data
# Out:
# {'classes': ['PRODUCT',
#   'ORG',
#   'LOC',
#   'PER',
#   'TIME',
#   'MONEY',
#   'EVENT',
#   'DATE',
#   'PROFESSION',
#   'FACILITY',
#   'CONTENT',
#   'FIELD OF STUDY',
#   'PROCESS',
#   'DOMAIN',
#   'ATTRIBUTE',
#   'GPE',
#   'YEAR',
#   'GOVERNMENT',
#   'ACTIVITY',
#   'EMOTION',
#   'ACTION',
#   'ENTERTAINMENT',
#   'MOVIE',
#   'LANGUAGE',
#   'QUANTITY'],
#  'annotations': [[' Movie pathutu vanthu trailer pakurvanga yaru\r',
#    {'entities': [[1, 14, 'ACTIVITY'], [41, 45, 'PER']]}],
#   [' Puthupetai dhanush  ah yarellam pathinga\r',
#    {'entities': [[1, 19, 'PER']]}],
#   [' Dhanush oda character ,puthu sa erukay , mass ta\r',
#    {'entities': [[1, 8, 'PER']]}],
#   [' vera level ippa pesungada mokka nu thalaivaaaaaa\r',
#    {'entities': [[1, 11, 'EMOTION'], [36, 49, 'PER']]}],
#   [' Thala mass . U1 bgm.     Vera level\r',
#    {'entities': [[1, 6, 'PER'], [14, 16, 'PER'], [26, 36, 'EMOTION']]}],
# ...

# %%
entity_names = ['PER', 'LOC', 'ORG', 'PRODUCT', 'TIME', 'MONEY','EVENT','DATE','PROFESSION','FACILITY','CONTENT','FIELD OF STUDY','PROCESS','DOMAIN','ATTRIBUTE','GPE','YEAR','GOVERNMENT','ACTIVITY','EMOTION','ACTION','ENTERTAINMENT','MOVIE','LANGUAGE','QUANTITY']
train_data1 = data['annotations']
train_data1 = [tuple(i) for i in train_data1]

# %%
train_data1
# Out:
# [(' Movie pathutu vanthu trailer pakurvanga yaru\r',
#   {'entities': [[1, 14, 'ACTIVITY'], [41, 45, 'PER']]}),
#  (' Puthupetai dhanush  ah yarellam pathinga\r',
#   {'entities': [[1, 19, 'PER']]}),
#  (' Dhanush oda character ,puthu sa erukay , mass ta\r',
#   {'entities': [[1, 8, 'PER']]}),
#  (' vera level ippa pesungada mokka nu thalaivaaaaaa\r',
#   {'entities': [[1, 11, 'EMOTION'], [36, 49, 'PER']]}),
#  (' Thala mass . U1 bgm.     Vera level\r',
#   {'entities': [[1, 6, 'PER'], [14, 16, 'PER'], [26, 36, 'EMOTION']]}),
#  (' ivara pathta death vadi madiri irukku\r', {'entities': [[1, 6, 'PER']]}),
#  (" 0:28 90's kids reference  Maadila irunthu kudicha Shakthiman kaapathvaaru\r",
#   {'entities': [[1, 5, 'TIME'],
#     [6, 10, 'TIME'],
#     [27, 34, 'LOC'],
#     [51, 61, 'PER']]}),
#  (' Aiyoo thala mass pannita thala\r',
#   {'entities': [[7, 12, 'PER'], [26, 31, 'PER']]}),
#  (' ENPT ku kaathu kadanthathellam oru nimishathula poiruchu\r',
# ...

# %%
for i in train_data1:
    if i[1]['entities'] == []:
        i[1]['entities'] = (0, 0, entity_name)
    else:
        i[1]['entities'][0] = tuple(i[1]['entities'][0])

# %%
len(train_data1)
# Out:
# 24

# %%
train_data.extend(train_data1)

# Store the result in train1
train_data
# Out:
# [('En mapla odi poi irukkan\r', {'entities': [(3, 8, 'PER')]}),
#  ('Naan college ku poren\r', {'entities': [(5, 12, 'ORG')]}),
#  ('En akka ku gift vaangi koduthen\r',
#   {'entities': [(3, 7, 'PER'), [11, 15, 'PRODUCT']]}),
#  ('Office ku late aagi iruken\r', {'entities': [(0, 6, 'ORG')]}),
#  ('Naan London ku ponen\r', {'entities': [(0, 4, 'PER'), [5, 11, 'LOC']]}),
#  ('En friend kalyanam nadakuthu\r',
#   {'entities': [(3, 9, 'PER'), [10, 18, 'EVENT']]}),
#  ('Namma ooru Chennai\r', {'entities': [(11, 18, 'LOC')]}),
#  ('Naan school la padichiruken\r', {'entities': [(5, 11, 'ORG')]}),
#  ('En amma office la work pannuva\r',
#   {'entities': [(3, 7, 'PER'), [8, 14, 'ORG']]}),
#  ('En friend car kitta poyi vandhurukka\r',
#   {'entities': [(3, 9, 'PER'), [10, 13, 'PRODUCT']]}),
#  ('Naan India ku poiruken\r', {'entities': [(0, 4, 'PER'), [5, 10, 'LOC']]}),
#  ('En teacher oru book kodutharu\r',
#   {'entities': [(3, 10, 'PER'), [15, 19, 'PRODUCT']]}),
# ...

# %%
len(train_data)
# Out:
# 437

# %%
import pandas as pd
import json
import os
os.chdir(r"C:\Users\Mohamed Kani P K\Downloads")

with open('annotations (7).json', 'r',encoding='utf-8') as f:
    data = json.load(f)

# %%
entity_names = ['PER', 'LOC', 'ORG', 'PRODUCT', 'TIME', 'MONEY','EVENT','DATE','PROFESSION','FACILITY','CONTENT','FIELD OF STUDY','PROCESS','DOMAIN','ATTRIBUTE','GPE','YEAR','GOVERNMENT','ACTIVITY','EMOTION','ACTION','ENTERTAINMENT','MOVIE','LANGUAGE','QUANTITY']
train_data1 = data['annotations']
train_data1 = [tuple(i) for i in train_data1]

# %%
for i in train_data1:
    if i[1]['entities'] == []:
        i[1]['entities'] = (0, 0, entity_name)
    else:
        i[1]['entities'][0] = tuple(i[1]['entities'][0])

# %%
len(train_data1)
# Out:
# 89

# %%
train_data.extend(train_data1)

# Store the result in train1
train_data
# Out:
# [('En mapla odi poi irukkan\r', {'entities': [(3, 8, 'PER')]}),
#  ('Naan college ku poren\r', {'entities': [(5, 12, 'ORG')]}),
#  ('En akka ku gift vaangi koduthen\r',
#   {'entities': [(3, 7, 'PER'), [11, 15, 'PRODUCT']]}),
#  ('Office ku late aagi iruken\r', {'entities': [(0, 6, 'ORG')]}),
#  ('Naan London ku ponen\r', {'entities': [(0, 4, 'PER'), [5, 11, 'LOC']]}),
#  ('En friend kalyanam nadakuthu\r',
#   {'entities': [(3, 9, 'PER'), [10, 18, 'EVENT']]}),
#  ('Namma ooru Chennai\r', {'entities': [(11, 18, 'LOC')]}),
#  ('Naan school la padichiruken\r', {'entities': [(5, 11, 'ORG')]}),
#  ('En amma office la work pannuva\r',
#   {'entities': [(3, 7, 'PER'), [8, 14, 'ORG']]}),
#  ('En friend car kitta poyi vandhurukka\r',
#   {'entities': [(3, 9, 'PER'), [10, 13, 'PRODUCT']]}),
#  ('Naan India ku poiruken\r', {'entities': [(0, 4, 'PER'), [5, 10, 'LOC']]}),
#  ('En teacher oru book kodutharu\r',
#   {'entities': [(3, 10, 'PER'), [15, 19, 'PRODUCT']]}),
# ...

# %%
len(train_data)
# Out:
# 526

# %%
import pandas as pd
import json
import os
os.chdir(r"C:\Users\Mohamed Kani P K\Downloads")

with open('annotations (9).json', 'r',encoding='utf-8') as f:
    data = json.load(f)
entity_names = ['PER', 'LOC', 'ORG', 'PRODUCT', 'TIME', 'MONEY','EVENT','DATE','PROFESSION','FACILITY','CONTENT','FIELD OF STUDY','PROCESS','DOMAIN','ATTRIBUTE','GPE','YEAR','GOVERNMENT','ACTIVITY','EMOTION','ACTION','ENTERTAINMENT','MOVIE','LANGUAGE','QUANTITY']
train_data1 = data['annotations']
train_data1 = [tuple(i) for i in train_data1]
for i in train_data1:
    if i[1]['entities'] == []:
        i[1]['entities'] = (0, 0, entity_name)
    else:
        i[1]['entities'][0] = tuple(i[1]['entities'][0])
train_data1
# Out:
# [('yenakku 3 manikku team meeting irukku.\r',
#   {'entities': [(0, 7, 'PER'), [8, 17, 'TIME'], [18, 30, 'EVENT']]}),
#  ('namakku 2 PM-kku conference call schedule aakirukku.\r',
#   {'entities': [(0, 7, 'PER'), [8, 16, 'TIME'], [17, 32, 'EVENT']]}),
#  ('namma upcoming project-kku ideas saerkkalaam.\r',
#   {'entities': [(0, 5, 'PER'), [6, 26, 'EVENT'], [27, 32, 'CONTENT']]}),
#  ('naan naalaikku project report mutikkanum.\r',
#   {'entities': [(0, 4, 'PER'), [5, 14, 'DATE'], [15, 29, 'CONTENT']]}),
#  ('yenakku latest version document anuppa mutiyumaa email laa.\r',
#   {'entities': [(0, 7, 'PER'), [49, 54, 'CONTENT']]}),
#  ('naan innaikku afternoon oru client meeting kaaka office-la irunthu velila poaraen.\r',
#   {'entities': [(0, 4, 'PER'),
#     [5, 13, 'DATE'],
#     [14, 23, 'DATE'],
#     [28, 42, 'EVENT'],
#     [49, 58, 'LOC'],
#     [67, 81, 'ACTION']]}),
#  ('naangka atuththa maasam oru team-building workshop- ai yaerpaatu panroam.\r',
#   {'entities': [(0, 7, 'PER'),
# ...

# %%
train_data.extend(train_data1)

# Store the result in train1
train_data
# Out:
# [('En mapla odi poi irukkan\r', {'entities': [(3, 8, 'PER')]}),
#  ('Naan college ku poren\r', {'entities': [(5, 12, 'ORG')]}),
#  ('En akka ku gift vaangi koduthen\r',
#   {'entities': [(3, 7, 'PER'), [11, 15, 'PRODUCT']]}),
#  ('Office ku late aagi iruken\r', {'entities': [(0, 6, 'ORG')]}),
#  ('Naan London ku ponen\r', {'entities': [(0, 4, 'PER'), [5, 11, 'LOC']]}),
#  ('En friend kalyanam nadakuthu\r',
#   {'entities': [(3, 9, 'PER'), [10, 18, 'EVENT']]}),
#  ('Namma ooru Chennai\r', {'entities': [(11, 18, 'LOC')]}),
#  ('Naan school la padichiruken\r', {'entities': [(5, 11, 'ORG')]}),
#  ('En amma office la work pannuva\r',
#   {'entities': [(3, 7, 'PER'), [8, 14, 'ORG']]}),
#  ('En friend car kitta poyi vandhurukka\r',
#   {'entities': [(3, 9, 'PER'), [10, 13, 'PRODUCT']]}),
#  ('Naan India ku poiruken\r', {'entities': [(0, 4, 'PER'), [5, 10, 'LOC']]}),
#  ('En teacher oru book kodutharu\r',
#   {'entities': [(3, 10, 'PER'), [15, 19, 'PRODUCT']]}),
# ...

# %%
len(train_data)
# Out:
# 542

# %%
import pandas as pd
import json
import os
os.chdir(r"C:\Users\Mohamed Kani P K\Downloads")

with open('annotations (10).json', 'r',encoding='utf-8') as f:
    data = json.load(f)
entity_names = ['PER', 'LOC', 'ORG', 'PRODUCT', 'TIME', 'MONEY','EVENT','DATE','PROFESSION','FACILITY','CONTENT','FIELD OF STUDY','PROCESS','DOMAIN','ATTRIBUTE','GPE','YEAR','GOVERNMENT','ACTIVITY','EMOTION','ACTION','ENTERTAINMENT','MOVIE','LANGUAGE','QUANTITY']
train_data1 = data['annotations']
train_data1 = [tuple(i) for i in train_data1]
for i in train_data1:
    if i[1]['entities'] == []:
        i[1]['entities'] = (0, 0, entity_name)
    else:
        i[1]['entities'][0] = tuple(i[1]['entities'][0])
train_data1
# Out:
# [('Michael Boston-il irukkiraar aana in Washington D.C. irukkiraar.\r',
#   {'entities': [(0, 7, 'PER'), [8, 17, 'LOC'], [37, 52, 'LOC']]}),
#  ('Louvre Museum-la nadakum exhibition intha maatham opening-aa irukkum.\r',
#   {'entities': [(0, 16, 'LOC'), [25, 35, 'EVENT']]}),
#  ('Mr. Khan ABC Tech Solutions-yin founder.\r',
#   {'entities': [(0, 8, 'PER'), [9, 31, 'ORG']]}),
#  ('Namma dinner reservation The Cheesecake Factory-il irukku.\r',
#   {'entities': [(0, 5, 'PER'), [25, 50, 'ORG']]}),
#  ('Emily Harvard Business School-il MBA padikkaranga.\r',
#   {'entities': [(0, 5, 'PER'), [6, 32, 'ORG'], [33, 36, 'FIELD OF STUDY']]}),
#  ('Kolkata-il nadakkum conference IBM-vaal hosted-aa.\r',
#   {'entities': [(0, 10, 'LOC'), [20, 30, 'EVENT'], [31, 39, 'ORG']]}),
#  ('Raju Mumbai-il irukkira friends-oda pesa porenaar.\r',
#   {'entities': [(0, 4, 'PER'), [5, 14, 'LOC'], [24, 35, 'PER']]}),
#  ('Sarah Paris-il irukkira fashion show-ku poga poraar.\r',
# ...

# %%
len(train_data1)
# Out:
# 54

# %%
train_data.extend(train_data1)

# Store the result in train1
train_data
# Out:
# [('En mapla odi poi irukkan\r', {'entities': [(3, 8, 'PER')]}),
#  ('Naan college ku poren\r', {'entities': [(5, 12, 'ORG')]}),
#  ('En akka ku gift vaangi koduthen\r',
#   {'entities': [(3, 7, 'PER'), [11, 15, 'PRODUCT']]}),
#  ('Office ku late aagi iruken\r', {'entities': [(0, 6, 'ORG')]}),
#  ('Naan London ku ponen\r', {'entities': [(0, 4, 'PER'), [5, 11, 'LOC']]}),
#  ('En friend kalyanam nadakuthu\r',
#   {'entities': [(3, 9, 'PER'), [10, 18, 'EVENT']]}),
#  ('Namma ooru Chennai\r', {'entities': [(11, 18, 'LOC')]}),
#  ('Naan school la padichiruken\r', {'entities': [(5, 11, 'ORG')]}),
#  ('En amma office la work pannuva\r',
#   {'entities': [(3, 7, 'PER'), [8, 14, 'ORG']]}),
#  ('En friend car kitta poyi vandhurukka\r',
#   {'entities': [(3, 9, 'PER'), [10, 13, 'PRODUCT']]}),
#  ('Naan India ku poiruken\r', {'entities': [(0, 4, 'PER'), [5, 10, 'LOC']]}),
#  ('En teacher oru book kodutharu\r',
#   {'entities': [(3, 10, 'PER'), [15, 19, 'PRODUCT']]}),
# ...

# %%
len(train_data)
# Out:
# 596

# %%
import pandas as pd
import json
import os
os.chdir(r"C:\Users\Mohamed Kani P K\Downloads")

with open(r"C:\Users\Mohamed Kani P K\Downloads\annotations (11).json", 'r',encoding='utf-8') as f:
    data = json.load(f)
entity_names = ['PER', 'LOC', 'ORG', 'PRODUCT', 'TIME', 'MONEY','EVENT','DATE','PROFESSION','FACILITY','CONTENT','FIELD OF STUDY','PROCESS','DOMAIN','ATTRIBUTE','GPE','YEAR','GOVERNMENT','ACTIVITY','EMOTION','ACTION','ENTERTAINMENT','MOVIE','LANGUAGE','QUANTITY']
train_data1 = data['annotations']
train_data1 = [tuple(i) for i in train_data1]
for i in train_data1:
    if i[1]['entities'] == []:
        i[1]['entities'] = (0, 0, entity_name)
    else:
        i[1]['entities'][0] = tuple(i[1]['entities'][0])
train_data1
train_data.extend(train_data1)

# Store the result in train1
train_data
# Out:
# [('En mapla odi poi irukkan\r', {'entities': [(3, 8, 'PER')]}),
#  ('Naan college ku poren\r', {'entities': [(5, 12, 'ORG')]}),
#  ('En akka ku gift vaangi koduthen\r',
#   {'entities': [(3, 7, 'PER'), [11, 15, 'PRODUCT']]}),
#  ('Office ku late aagi iruken\r', {'entities': [(0, 6, 'ORG')]}),
#  ('Naan London ku ponen\r', {'entities': [(0, 4, 'PER'), [5, 11, 'LOC']]}),
#  ('En friend kalyanam nadakuthu\r',
#   {'entities': [(3, 9, 'PER'), [10, 18, 'EVENT']]}),
#  ('Namma ooru Chennai\r', {'entities': [(11, 18, 'LOC')]}),
#  ('Naan school la padichiruken\r', {'entities': [(5, 11, 'ORG')]}),
#  ('En amma office la work pannuva\r',
#   {'entities': [(3, 7, 'PER'), [8, 14, 'ORG']]}),
#  ('En friend car kitta poyi vandhurukka\r',
#   {'entities': [(3, 9, 'PER'), [10, 13, 'PRODUCT']]}),
#  ('Naan India ku poiruken\r', {'entities': [(0, 4, 'PER'), [5, 10, 'LOC']]}),
#  ('En teacher oru book kodutharu\r',
#   {'entities': [(3, 10, 'PER'), [15, 19, 'PRODUCT']]}),
# ...

# %%
len(train_data)
# Out:
# 607

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming entity_names is defined somewhere
entity_counts = {entity: 0 for entity in entity_names}

# Assuming train_data is defined somewhere
for _, annot in train_data:
    entities = annot['entities']
    for entity in entities:
        entity_type = entity[2]
        if entity_type in entity_counts:
            entity_counts[entity_type] += 1

# Filter out entities with count 0
x_labels = [entity_type for entity_type, count in entity_counts.items() if count > 0]
y_values = [count for count in entity_counts.values() if count > 0]

# Bar Chart
plt.figure(figsize=(8, 6))
plt.bar(x_labels, y_values, color='lightpink')
plt.xlabel('Entity Types')
plt.ylabel('Counts')
plt.title('Counts of Entities')
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
#Define the file name
file_name = r"D:\Review_NLP\train_data.txt"

# Convert the list to a string
data_string = repr(train_data)

# Write the string to a file
with open(file_name, "w", encoding="utf-8") as file:
    file.write(data_string)

# %%
import pandas as pd
import os
from tqdm import tqdm
import spacy
from spacy.tokens import DocBin
nlp = spacy.load("en_core_web_lg") 

db = DocBin() 

for text, annot in tqdm(train_data): 
    doc = nlp.make_doc(text) 
    ents = []
    for start, end, label in annot["entities"]:
        span = doc.char_span(start, end, label=label, alignment_mode="contract")
        if span is None:
            print("Skipping entity")
        else:
            ents.append(span)
    doc.ents = ents 
    db.add(doc)
output_dir=r"D:\Review_NLP"
os.chdir(output_dir)
db.to_disk("./train.spacy")
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 607/607 [00:00<00:00, 2929.77it/s]

# %%
# !python -m spacy init fill-config base_config.cfg config.cfg
# Out:
# [+] Auto-filled config with all values
# [+] Saved config
# config.cfg
# You can now add your data and train your pipeline:
# python -m spacy train config.cfg --paths.train ./train.spacy --paths.dev ./dev.spacy

# %%
#!python -m spacy train config.cfg --output ./output --paths.train ./train.spacy --paths.dev ./train.spacy

# %% [markdown]
# <img src="D:/Review_NLP/pipeline.png" alt="Pipeline">

# %%
import spacy
import matplotlib.pyplot as plt  # Add this line to import matplotlib
import numpy as np
# Load the custom model
nlp = spacy.load(r"D:\Review_NLP\output\model-best")

# Get input from the user
text = input("Enter the text: ")

# Process the text with the loaded model
doc = nlp(text)

# Render the named entities
spacy.displacy.render(doc, style="ent", jupyter=True)
entity_counts = {}
for ent in doc.ents:
    entity_type = ent.label_
    if entity_type in entity_counts:
        entity_counts[entity_type] += 1
    else:
        entity_counts[entity_type] = 1

# Print the entity counts
for entity_type, count in entity_counts.items():
    print(f"{entity_type} - {count}")
# Plotting the bar chart
plt.figure(figsize=(8, 6))
plt.bar(entity_counts.keys(), entity_counts.values(), color='skyblue')
plt.xlabel('Entity Types')
plt.ylabel('Counts')
plt.title('Entity Type Occurrences in Input Text')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Enter the text:  Avanoda friend Facebook-la post pannitaan
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Avanoda friend
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Facebook-la
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  post pannitaan</div></span>
# PER - 1
# ORG - 1

# %%
import spacy
import matplotlib.pyplot as plt  # Add this line to import matplotlib
import numpy as np
# Load the custom model
nlp = spacy.load(r"D:\Review_NLP\output\model-best")

# Get input from the user
text = input("Enter the text: ")

# Process the text with the loaded model
doc = nlp(text)

# Render the named entities
spacy.displacy.render(doc, style="ent", jupyter=True)
entity_counts = {}
for ent in doc.ents:
    entity_type = ent.label_
    if entity_type in entity_counts:
        entity_counts[entity_type] += 1
    else:
        entity_counts[entity_type] = 1

# Print the entity counts
for entity_type, count in entity_counts.items():
    print(f"{entity_type} - {count}")
# Out:
# Enter the text:  Avanoda birthday June 15-ku varum.
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Avanoda
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     birthday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     June 15-ku
# ...
